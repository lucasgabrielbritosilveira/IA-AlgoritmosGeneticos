# %% [markdown]
# # Análise Experimento 3

# %%
import pandas as pd

caminho_csv = './resultados_experimento3MOCADO.csv'

df = pd.read_csv(caminho_csv)

df.head()
# Out:
#     pop_size  geracoes  elite_rate  mutation_rate         melhor_solucao  \
# 0        100       100         0.2            0.1  [7 3 6 5 0 8 1 2 4 9]
# 1        100       100         0.2            0.1  [4 8 6 0 9 3 7 5 1 2]
# 2        100       100         0.2            0.1  [8 6 5 9 2 4 7 0 1 3]
# 3        100       100         0.2            0.1  [8 6 3 1 0 9 7 4 2 5]
# 4        100       100         0.2            0.1  [6 2 0 5 8 1 9 7 3 4]
# 5        100       100         0.2            0.1  [3 7 0 4 1 2 8 6 9 5]
# 6        100       100         0.2            0.1  [6 0 5 9 1 8 7 2 4 3]
# 7        100       100         0.2            0.1  [0 5 2 8 6 4 7 1 3 9]
# 8        100       100         0.2            0.1  [0 4 6 3 1 9 5 2 8 7]
# 9        100       100         0.2            0.1  [2 5 6 7 4 9 8 0 3 1]
# 10       100       100         0.2            0.1  [9 0 2 4 6 5 1 7 8 3]
# 11       100       100         0.2            0.1  [0 8 1 4 6 3 2 7 9 5]
# 12       100       100         0.2            0.1  [0 2 3 4 7 1 6 8 5 9]
# 13       100       100         0.2            0.1  [9 8 6 2 0 7 1 5 4 3]
# 14       100       100         0.2            0.1  [6 4 8 1 0 2 5 7 3 9]
# 15       100       100         0.2            0.1  [8 4 0 7 1 2 6 3 9 5]
# 16       100       100         0.2            0.1  [0 5 8 3 4 7 6 1 2 9]
# 17       100       100         0.2            0.1  [4 1 7 6 0 9 2 3 5 8]
# 18       100       100         0.2            0.1  [6 1 8 9 7 4 5 0 2 3]
# 19       100       100         0.2            0.1  [4 7 9 1 6 0 5 8 3 2]
# 20       100       100         0.2            0.1  [7 6 0 3 9 5 1 8 4 2]
# 21       100       100         0.2            0.1  [2 9 7 3 0 5 1 8 4 6]
# 22       100       100         0.2            0.1  [4 8 1 0 6 2 7 9 3 5]
# 23       100       100         0.2            0.1  [4 8 6 0 9 5 7 1 3 2]
# 24       100       100         0.2            0.1  [9 2 0 1 6 3 4 8 7 5]
# 25       100       100         0.2            0.1  [0 5 4 3 8 2 1 9 6 7]
# 26       100       100         0.2            0.1  [8 7 4 2 9 1 5 0 3 6]
# 27       100       100         0.2            0.1  [5 2 1 4 7 0 8 3 6 9]
# 28       100       100         0.2            0.1  [9 6 8 5 0 2 1 4 7 3]
# 29       100       100         0.2            0.1  [8 2 5 7 4 1 3 0 9 6]
# 30       100       100         0.2            0.1  [4 1 9 2 7 3 0 5 6 8]
# 31       100       100         0.2            0.1  [4 1 9 2 7 3 0 5 6 8]
# 32       100       100         0.2            0.1  [1 3 4 2 9 8 7 6 5 0]
# 33       100       100         0.2            0.1  [1 3 4 5 9 8 6 7 2 0]
# 34       100       100         0.2            0.1  [0 5 4 6 7 8 3 1 2 9]
# 35       100       100         0.2            0.1  [0 5 4 6 7 8 3 1 2 9]
# 36       100       100         0.2            0.1  [9 4 6 1 2 3 0 5 8 7]
# 37       100       100         0.2            0.1  [4 0 2 7 1 6 3 9 8 5]
# 38       100       100         0.2            0.1  [6 7 3 0 9 4 2 8 5 1]
# 39       100       100         0.2            0.1  [2 7 3 9 0 8 6 4 1 5]
#
#     melhor_custo  tempo_execucao_s  geracao_melhor_custo  \
# 0         5032.0          1.610123                    25
# 1         5152.0          1.563194                    16
# 2         5859.0          1.564897                    18
# 3         6066.0          1.587555                     5
# 4         5046.0          1.577642                    28
# 5         4932.0          1.538087                    17
# 6         5863.0          1.595056                    42
# 7         5807.0          1.530867                    44
# 8         5785.0          1.617127                    20
# 9         5672.0          1.513253                    20
# 10        6038.0          1.792591                     9
# 11        5968.0          1.532145                    20
# 12        6862.0          1.468448                    15
# 13        6894.0          1.464770                    35
# 14        6190.0          1.662357                    29
# 15        6234.0          1.528158                    22
# 16        5576.0          1.516606                    27
# 17        5605.0          1.622558                    33
# 18        5730.0          1.576884                     7
# 19        5708.0          1.546918                     3
# 20        4309.0          1.513361                    21
# 21        4204.0          1.534164                    32
# 22        4396.0          1.522906                    13
# 23        4346.0          1.564525                    16
# 24        8103.0          1.515698                    25
# 25        8373.0          1.555970                     3
# 26        5583.0          1.507102                    23
# 27        5613.0          1.664589                    12
# 28        4897.0          1.548637                    41
# 29        4916.0          1.520104                    12
# 30        4800.0          1.581155                    24
# 31        4800.0          1.568870                    12
# 32        4883.0          1.578120                     5
# 33        4796.0          1.562027                    25
# 34        5331.0          1.542498                     9
# 35        5331.0          1.524364                    10
# 36        5940.0          1.566932                     0
# 37        5734.0          1.519235                     8
# 38        7065.0          1.496378                    63
# 39        7073.0          1.489476                    14
#
#                                          configuracao     elitism   selection  \
# 0   {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 1   {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 2   {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 3   {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 4   {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 5   {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 6   {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 7   {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 8   {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 9   {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 10  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 11  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 12  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 13  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 14  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 15  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 16  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 17  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 18  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 19  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 20  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 21  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 22  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 23  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 24  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 25  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 26  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 27  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 28  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 29  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 30  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 31  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 32  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 33  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 34  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 35  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 36  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 37  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
# 38  {'selection': 'tournament', 'crossover': 'cx',...      simple  tournament
# 39  {'selection': 'tournament', 'crossover': 'cx',...  tournament  tournament
#
#    crossover mutation
# 0         cx     swap
# 1         cx     swap
# 2         cx     swap
# 3         cx     swap
# 4         cx     swap
# 5         cx     swap
# 6         cx     swap
# 7         cx     swap
# 8         cx     swap
# 9         cx     swap
# 10        cx     swap
# 11        cx     swap
# 12        cx     swap
# 13        cx     swap
# 14        cx     swap
# 15        cx     swap
# 16        cx     swap
# 17        cx     swap
# 18        cx     swap
# 19        cx     swap
# 20        cx     swap
# 21        cx     swap
# 22        cx     swap
# 23        cx     swap
# 24        cx     swap
# 25        cx     swap
# 26        cx     swap
# 27        cx     swap
# 28        cx     swap
# 29        cx     swap
# 30        cx     swap
# 31        cx     swap
# 32        cx     swap
# 33        cx     swap
# 34        cx     swap
# 35        cx     swap
# 36        cx     swap
# 37        cx     swap
# 38        cx     swap
# 39        cx     swap

# %%
import ast

# Converte a string da coluna 'configuracao' para dicionário e expande em colunas
config_df = df['configuracao'].apply(lambda x: ast.literal_eval(x)).apply(pd.Series)

# Renomeia as colunas, se necessário
config_df.rename(columns={'selection': 'selection_type', 'crossover': 'crossover_type', 'mutation': 'mutation_type', 'elitism': 'elitismo' }, inplace=True)

# Concatena o DataFrame original com as novas colunas
df_expanded = pd.concat([df.drop(columns=['configuracao']), config_df], axis=1)
df_expanded.head()
# Out:
#    pop_size  geracoes  elite_rate  mutation_rate         melhor_solucao  \
# 0       100       100         0.2            0.1  [7 3 6 5 0 8 1 2 4 9]
# 1       100       100         0.2            0.1  [4 8 6 0 9 3 7 5 1 2]
# 2       100       100         0.2            0.1  [8 6 5 9 2 4 7 0 1 3]
# 3       100       100         0.2            0.1  [8 6 3 1 0 9 7 4 2 5]
# 4       100       100         0.2            0.1  [6 2 0 5 8 1 9 7 3 4]
#
#    melhor_custo  tempo_execucao_s  geracao_melhor_custo     elitism  \
# 0        5032.0          1.610123                    25      simple
# 1        5152.0          1.563194                    16  tournament
# 2        5859.0          1.564897                    18      simple
# 3        6066.0          1.587555                     5  tournament
# 4        5046.0          1.577642                    28      simple
#
#     selection crossover mutation selection_type crossover_type    elitismo  \
# 0  tournament        cx     swap     tournament             cx      simple
# 1  tournament        cx     swap     tournament             cx  tournament
# 2  tournament        cx     swap     tournament             cx      simple
# 3  tournament        cx     swap     tournament             cx  tournament
# 4  tournament        cx     swap     tournament             cx      simple
#
#   mutation_type
# 0          swap
# 1          swap
# 2          swap
# 3          swap
# 4          swap

# %%
fitness_means = df_expanded.groupby('elitism')['melhor_custo'].mean().reset_index(name='mean_fitness')
fitness_stds = df_expanded.groupby('elitism')['melhor_custo'].std().reset_index(name='std_fitness')
time_means = df_expanded.groupby('elitism')['tempo_execucao_s'].mean().reset_index(name='mean_execution_time')
geracao_means = df_expanded.groupby('elitism')['geracao_melhor_custo'].mean().reset_index(name='mean_generation_best_cost')

# Juntando tudo em um único DataFrame
analysis_summary = fitness_means.merge(fitness_stds, on='elitism') \
                                .merge(time_means, on='elitism') \
                                .merge(geracao_means, on='elitism')

analysis_summary
# Out:
#       elitism  mean_fitness  std_fitness  mean_execution_time  \
# 0      simple        5664.4   924.269578             1.567726
# 1  tournament        5661.2   981.032249             1.546541
#
#    mean_generation_best_cost
# 0                      22.20
# 1                      17.95

# %% [markdown]
# ## Análise do Custo Médio

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(analysis_summary['elitism'], analysis_summary['mean_fitness'], alpha=0.7)
plt.ylabel('Média do Melhor Custo (Fitness)')
plt.title('Comparação do Fitness Médio por Tipo de Seleção')
plt.show()

# %% [markdown]
# ## Análise de Tempo Médio de Execução

# %%
plt.figure(figsize=(8, 5))
plt.bar(analysis_summary['elitism'], analysis_summary['mean_execution_time'], alpha=0.7)
plt.ylabel('Tempo Médio de Execução (s)')
plt.title('Tempo Médio de Execução por Tipo de Seleção')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(analysis_summary['elitism'], analysis_summary['mean_generation_best_cost'], alpha=0.7)
plt.ylabel('Geração Média do Melhor Custo')
plt.title('Geração Média em que o Melhor Custo foi Encontrado')
plt.show()

# %%
import pandas as pd

# Criar um DataFrame para armazenar os resultados da comparação, considerando empates corretamente
comparisons = []

for i in range(0, len(df), 2):
    row1 = df.iloc[i]
    row2 = df.iloc[i + 1]

    #  Comparação do melhor custo (fitness)
    if row1['melhor_custo'] < row2['melhor_custo']:
        melhor_custo_vencedor = row1['elitism']
    elif row1['melhor_custo'] > row2['melhor_custo']:
        melhor_custo_vencedor = row2['elitism']
    else:
        melhor_custo_vencedor = 'empate'

    #  Comparação do tempo (geração do melhor custo)
    if row1['geracao_melhor_custo'] < row2['geracao_melhor_custo']:
        geracao_vencedor = row1['elitism']
    elif row1['geracao_melhor_custo'] > row2['geracao_melhor_custo']:
        geracao_vencedor = row2['elitism']
    else:
        geracao_vencedor = 'empate'

    comparisons.append({
        'par': i // 2 + 1,
        'melhor_custo_vencedor': melhor_custo_vencedor,
        'geracao_vencedor': geracao_vencedor
    })

# Transformar os resultados em DataFrame
comparison_df = pd.DataFrame(comparisons)

# Contagem de vitórias e empates em cada categoria
melhor_custo_counts = comparison_df['melhor_custo_vencedor'].value_counts().reset_index()
melhor_custo_counts.columns = ['resultado', 'vezes_melhor_custo']

geracao_counts = comparison_df['geracao_vencedor'].value_counts().reset_index()
geracao_counts.columns = ['resultado', 'vezes_mais_rapido']

#  Unir os resultados em uma tabela final
final_comparison = pd.merge(melhor_custo_counts, geracao_counts, on='resultado', how='outer').fillna(0)

final_comparison
# Out:
#     resultado  vezes_melhor_custo  vezes_mais_rapido
# 0      empate                   2                  1
# 1      simple                   9                  9
# 2  tournament                   9                 10

# %%
# Gráfico de barras: Número de vitórias em Melhor Custo
plt.figure(figsize=(8, 5))
plt.bar(final_comparison['resultado'], final_comparison['vezes_melhor_custo'], color=['skyblue', 'salmon', 'gray'])
plt.ylabel('Número de Vitórias')
plt.title('Número de Vitórias em Melhor Custo (Fitness)')
plt.ylim(0, final_comparison[['vezes_melhor_custo']].values.max() + 2)
for index, value in enumerate(final_comparison['vezes_melhor_custo']):
    plt.text(index, value + 0.1, str(int(value)), ha='center')
plt.show()

#  Gráfico de barras: Número de vitórias em Tempo de Convergência
plt.figure(figsize=(8, 5))
plt.bar(final_comparison['resultado'], final_comparison['vezes_mais_rapido'], color=['lightgreen', 'orange', 'gray'])
plt.ylabel('Número de Vitórias')
plt.title('Número de Vitórias em Tempo de Convergência (Geração do Melhor Custo)')
plt.ylim(0, final_comparison[['vezes_mais_rapido']].values.max() + 2)
for index, value in enumerate(final_comparison['vezes_mais_rapido']):
    plt.text(index, value + 0.1, str(int(value)), ha='center')
plt.show()

plt.show()
