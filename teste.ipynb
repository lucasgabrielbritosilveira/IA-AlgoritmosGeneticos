# %%
import itertools
import pandas as pd
from environment import Environment
from algorithm.genetic_algorithm import GeneticAlgorithm

def testar_parametros(n, distance_matrix, flow_matrix):
    # Parâmetros a serem testados
    lista_pop_sizes = [50, 100, 150]
    lista_geracoes = [50, 100, 200]
    lista_elite_sizes = [1, 2, 4]
    lista_mutation_rates = [0.05, 0.1, 0.15]
    
    # Gerar todas as combinações possíveis
    combinacoes = itertools.product(
        lista_pop_sizes, 
        lista_geracoes, 
        lista_elite_sizes, 
        lista_mutation_rates
    )
    
    total_combinacoes = (
        len(lista_pop_sizes) 
        * len(lista_geracoes) 
        * len(lista_elite_sizes) 
        * len(lista_mutation_rates)
    )
    
    resultados = []
    
    for idx, (pop_size, geracoes, elite_size, mutation_rate) in enumerate(combinacoes, start=1):
        print(f"== Execução {idx}/{total_combinacoes} ==")
        print("Executando GA com parâmetros:")
        print(f"  - Tamanho da População: {pop_size}")
        print(f"  - Número de Gerações: {geracoes}")
        print(f"  - Elitismo (tamanho fixo): {elite_size}")
        print(f"  - Taxa de Mutação: {mutation_rate}")
        print("Inovando e pensando fora da caixinha para obter resultados de alta performance...\n")
        
        # Instancia o GA com os parâmetros
        ga = GeneticAlgorithm(
            n=n,
            distance_matrix=distance_matrix,
            flow_matrix=flow_matrix,
            pop_size=pop_size,
            generations=geracoes,
            mutation_rate=mutation_rate,
            elitism_type="fixed",       
            selection_type="tournament",
            crossover_type="ox",        
            mutation_type="swap",       
            elite_size=elite_size,
            min_elite=1,
            max_elite=5
        )
        
        # Executa o GA
        best_chromosome, best_fitness, cost_history = ga.run(show_progress=False)
        
        # Armazena resultado
        resultados.append({
            "pop_size": pop_size,
            "geracoes": geracoes,
            "elite_size": elite_size,
            "mutation_rate": mutation_rate,
            "melhor_solucao": best_chromosome,
            "melhor_custo": best_fitness,
        })
        
        print(f"Melhor Custo Encontrado: {best_fitness}")
        print("-"*60)
    
    # Converte a lista de dicionários para DataFrame para facilitar a análise
    df_resultados = pd.DataFrame(resultados)
    
    return df_resultados

# %%
n = 5
distance_matrix, flow_matrix = Environment(n)
df_final = testar_parametros(n, distance_matrix, flow_matrix)
print("\nTabela de Resultados Consolidada:")
df_final
# Out:
# == Execução 1/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 2/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 3/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 4/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 5/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 6/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 7/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 8/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 9/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 10/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 11/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 12/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 13/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 14/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 15/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 16/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 17/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 18/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 19/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 20/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 21/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 22/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 23/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 24/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 25/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 26/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 27/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 28/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 29/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 30/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 31/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 32/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 33/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 34/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 35/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 36/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 37/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 38/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 39/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 40/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 41/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 42/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 43/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 44/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 45/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 46/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 47/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 48/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 49/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 50/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 51/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 52/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 53/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 54/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 55/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 56/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 57/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 58/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 59/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 60/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 61/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 62/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 63/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 64/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 65/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 66/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 67/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 68/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 69/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 70/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 71/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 72/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 73/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 74/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 75/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 76/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 77/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 78/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 79/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 80/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
# == Execução 81/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 1404.0
# ------------------------------------------------------------
#
# Tabela de Resultados Consolidada:
#     pop_size  geracoes  elite_size  mutation_rate   melhor_solucao  \
# 0         50        50           1           0.05  [0, 2, 3, 4, 1]
# 1         50        50           1           0.10  [0, 2, 3, 4, 1]
# 2         50        50           1           0.15  [0, 2, 3, 4, 1]
# 3         50        50           2           0.05  [0, 2, 3, 4, 1]
# 4         50        50           2           0.10  [0, 2, 3, 4, 1]
# ..       ...       ...         ...            ...              ...
# 76       150       200           2           0.10  [0, 2, 3, 4, 1]
# 77       150       200           2           0.15  [0, 2, 3, 4, 1]
# 78       150       200           4           0.05  [0, 2, 3, 4, 1]
# 79       150       200           4           0.10  [0, 2, 3, 4, 1]
# 80       150       200           4           0.15  [0, 2, 3, 4, 1]
#
#     melhor_custo
# 0         1404.0
# 1         1404.0
# 2         1404.0
# 3         1404.0
# 4         1404.0
# ..           ...
# 76        1404.0
# 77        1404.0
# 78        1404.0
# 79        1404.0
# 80        1404.0
#
# [81 rows x 6 columns]

# %%
df_final
# Out:
#     pop_size  geracoes  elite_size  mutation_rate   melhor_solucao  \
# 0         50        50           1           0.05  [1, 2, 0, 3, 4]
# 1         50        50           1           0.10  [1, 2, 0, 3, 4]
# 2         50        50           1           0.15  [4, 0, 2, 3, 1]
# 3         50        50           2           0.05  [1, 2, 0, 3, 4]
# 4         50        50           2           0.10  [4, 0, 2, 3, 1]
# ..       ...       ...         ...            ...              ...
# 76       150       200           2           0.10  [1, 2, 0, 3, 4]
# 77       150       200           2           0.15  [1, 2, 0, 3, 4]
# 78       150       200           4           0.05  [1, 2, 0, 3, 4]
# 79       150       200           4           0.10  [1, 2, 0, 3, 4]
# 80       150       200           4           0.15  [1, 2, 0, 3, 4]
#
#     melhor_custo
# 0          710.0
# 1          710.0
# 2          732.0
# 3          710.0
# 4          732.0
# ..           ...
# 76         710.0
# 77         710.0
# 78         710.0
# 79         710.0
# 80         710.0
#
# [81 rows x 6 columns]

# %%
# 1. Encontrar o menor valor de "melhor_custo"
menor_custo = df_final["melhor_custo"].min()

# 2. Filtrar todas as linhas que possuem esse menor custo
linhas_melhores = df_final.loc[df_final["melhor_custo"] == menor_custo]
linhas_melhores.head(len(linhas_melhores))
# Out:
#     pop_size  geracoes  elite_size  mutation_rate   melhor_solucao  \
# 0         50        50           1           0.05  [1, 2, 0, 3, 4]
# 1         50        50           1           0.10  [1, 2, 0, 3, 4]
# 3         50        50           2           0.05  [1, 2, 0, 3, 4]
# 5         50        50           2           0.15  [1, 2, 0, 3, 4]
# 6         50        50           4           0.05  [1, 2, 0, 3, 4]
# ..       ...       ...         ...            ...              ...
# 76       150       200           2           0.10  [1, 2, 0, 3, 4]
# 77       150       200           2           0.15  [1, 2, 0, 3, 4]
# 78       150       200           4           0.05  [1, 2, 0, 3, 4]
# 79       150       200           4           0.10  [1, 2, 0, 3, 4]
# 80       150       200           4           0.15  [1, 2, 0, 3, 4]
#
#     melhor_custo
# 0          710.0
# 1          710.0
# 3          710.0
# 5          710.0
# 6          710.0
# ..           ...
# 76         710.0
# 77         710.0
# 78         710.0
# 79         710.0
# 80         710.0
#
# [75 rows x 6 columns]

# %%
# print(f"Quantidade de linhas com melhor custo: {len(linhas_melhores)}")

# %%
from algorithm.individual import Individual

indiv = Individual([5, 8, 6, 4, 7, 3, 1, 9, 2, 0])
indiv.calculate_fitness(distance_matrix, flow_matrix)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 4
#       1 from algorithm.individual import Individual
#       3 indiv = Individual([5, 8, 6, 4, 7, 3, 1, 9, 2, 0])
# ----> 4 indiv.calculate_fitness(distance_matrix, flow_matrix)
#
# File c:\Users\Carlo\OneDrive\Área de Trabalho\IA-AlgoritmosGeneticos\algorithm\individual.py:14, in Individual.calculate_fitness(self, dist_matrix, flow_matrix)
#      11     for i in range(size - 1):
#      12         for j in range(i, size):
#      13             self.fitness += (dist_matrix[i][j] *
# ---> 14                            flow_matrix[self.chromosome[i]][self.chromosome[j]])
#      15 return self.fitness
#
# IndexError: index 5 is out of bounds for axis 0 with size 5
