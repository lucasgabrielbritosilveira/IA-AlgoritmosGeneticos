# %%
import itertools
import pandas as pd
from environment import Environment
from algorithm.genetic_algorithm import GeneticAlgorithm

def testar_parametros(n, distance_matrix, flow_matrix):
    # Parâmetros a serem testados
    lista_pop_sizes = [50, 100, 150]
    lista_geracoes = [50, 100, 200]
    lista_elite_sizes = [1, 2, 4]
    lista_mutation_rates = [0.05, 0.1, 0.15]
    
    # Gerar todas as combinações possíveis
    combinacoes = itertools.product(
        lista_pop_sizes, 
        lista_geracoes, 
        lista_elite_sizes, 
        lista_mutation_rates
    )
    
    total_combinacoes = (
        len(lista_pop_sizes) 
        * len(lista_geracoes) 
        * len(lista_elite_sizes) 
        * len(lista_mutation_rates)
    )
    
    resultados = []
    
    for idx, (pop_size, geracoes, elite_size, mutation_rate) in enumerate(combinacoes, start=1):
        print(f"== Execução {idx}/{total_combinacoes} ==")
        print("Executando GA com parâmetros:")
        print(f"  - Tamanho da População: {pop_size}")
        print(f"  - Número de Gerações: {geracoes}")
        print(f"  - Elitismo (tamanho fixo): {elite_size}")
        print(f"  - Taxa de Mutação: {mutation_rate}")
        print("Inovando e pensando fora da caixinha para obter resultados de alta performance...\n")
        
        # Instancia o GA com os parâmetros
        ga = GeneticAlgorithm(
            n=n,
            distance_matrix=distance_matrix,
            flow_matrix=flow_matrix,
            pop_size=pop_size,
            generations=geracoes,
            mutation_rate=mutation_rate,
            elitism_type="fixed",       
            selection_type="tournament",
            crossover_type="ox",        
            mutation_type="swap",       
            elite_size=elite_size,
            min_elite=1,
            max_elite=5
        )
        
        # Executa o GA
        best_chromosome, best_fitness, cost_history = ga.run(show_progress=False)
        
        # Armazena resultado
        resultados.append({
            "pop_size": pop_size,
            "geracoes": geracoes,
            "elite_size": elite_size,
            "mutation_rate": mutation_rate,
            "melhor_solucao": best_chromosome,
            "melhor_custo": best_fitness,
        })
        
        print(f"Melhor Custo Encontrado: {best_fitness}")
        print("-"*60)
    
    # Converte a lista de dicionários para DataFrame para facilitar a análise
    df_resultados = pd.DataFrame(resultados)
    
    return df_resultados

# Exemplo de chamada (assumindo que distance_matrix e flow_matrix já estejam disponíveis)
if __name__ == "__main__":
    n = 10
    distance_matrix, flow_matrix = Environment(n)
    df_final = testar_parametros(n, distance_matrix, flow_matrix)
    print("\nTabela de Resultados Consolidada:")
    df_final
# Out:
# == Execução 1/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12516.0
# ------------------------------------------------------------
# == Execução 2/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11872.0
# ------------------------------------------------------------
# == Execução 3/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 4/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 5/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 6/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11884.0
# ------------------------------------------------------------
# == Execução 7/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12086.0
# ------------------------------------------------------------
# == Execução 8/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12008.0
# ------------------------------------------------------------
# == Execução 9/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 10/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 11/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12102.0
# ------------------------------------------------------------
# == Execução 12/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 13/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 14/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 15/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12086.0
# ------------------------------------------------------------
# == Execução 16/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11884.0
# ------------------------------------------------------------
# == Execução 17/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 18/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 19/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12028.0
# ------------------------------------------------------------
# == Execução 20/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12034.0
# ------------------------------------------------------------
# == Execução 21/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 22/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 23/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 24/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 25/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 26/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 27/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 50
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 28/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 29/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 30/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 31/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 32/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 33/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 34/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12020.0
# ------------------------------------------------------------
# == Execução 35/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 36/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 37/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 38/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 39/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 40/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 41/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 42/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 43/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 44/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 45/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 46/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 47/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 48/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 49/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 50/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12330.0
# ------------------------------------------------------------
# == Execução 51/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11884.0
# ------------------------------------------------------------
# == Execução 52/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11906.0
# ------------------------------------------------------------
# == Execução 53/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 54/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 100
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 55/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12006.0
# ------------------------------------------------------------
# == Execução 56/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 57/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 58/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 59/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11906.0
# ------------------------------------------------------------
# == Execução 60/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 61/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 62/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12028.0
# ------------------------------------------------------------
# == Execução 63/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 50
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 64/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 65/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 66/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 67/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12114.0
# ------------------------------------------------------------
# == Execução 68/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11806.0
# ------------------------------------------------------------
# == Execução 69/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 70/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11872.0
# ------------------------------------------------------------
# == Execução 71/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11676.0
# ------------------------------------------------------------
# == Execução 72/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 100
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 73/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 12020.0
# ------------------------------------------------------------
# == Execução 74/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 75/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 1
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 76/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 77/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11900.0
# ------------------------------------------------------------
# == Execução 78/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 2
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11762.0
# ------------------------------------------------------------
# == Execução 79/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.05
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11872.0
# ------------------------------------------------------------
# == Execução 80/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.1
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
# == Execução 81/81 ==
# Executando GA com parâmetros:
#   - Tamanho da População: 150
#   - Número de Gerações: 200
#   - Elitismo (tamanho fixo): 4
#   - Taxa de Mutação: 0.15
# Inovando e pensando fora da caixinha para obter resultados de alta performance...
#
# Melhor Custo Encontrado: 11790.0
# ------------------------------------------------------------
#
# Tabela de Resultados Consolidada:

# %%
df_final
# Out:
#     pop_size  geracoes  elite_size  mutation_rate  \
# 0         50        50           1           0.05
# 1         50        50           1           0.10
# 2         50        50           1           0.15
# 3         50        50           2           0.05
# 4         50        50           2           0.10
# ..       ...       ...         ...            ...
# 76       150       200           2           0.10
# 77       150       200           2           0.15
# 78       150       200           4           0.05
# 79       150       200           4           0.10
# 80       150       200           4           0.15
#
#                     melhor_solucao  melhor_custo
# 0   [7, 6, 8, 9, 4, 5, 3, 2, 1, 0]       12516.0
# 1   [2, 4, 8, 3, 1, 9, 6, 5, 7, 0]       11872.0
# 2   [9, 8, 5, 6, 7, 3, 4, 1, 2, 0]       11790.0
# 3   [8, 5, 3, 4, 2, 0, 1, 6, 7, 9]       11900.0
# 4   [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# ..                             ...           ...
# 76  [8, 5, 3, 4, 2, 0, 1, 6, 7, 9]       11900.0
# 77  [1, 5, 8, 6, 2, 0, 3, 4, 7, 9]       11762.0
# 78  [2, 4, 8, 3, 1, 9, 6, 5, 7, 0]       11872.0
# 79  [9, 8, 5, 6, 7, 3, 4, 1, 2, 0]       11790.0
# 80  [9, 8, 5, 6, 7, 3, 4, 1, 2, 0]       11790.0
#
# [81 rows x 6 columns]

# %%
# 1. Encontrar o menor valor de "melhor_custo"
menor_custo = df_final["melhor_custo"].min()

# 2. Filtrar todas as linhas que possuem esse menor custo
linhas_melhores = df_final.loc[df_final["melhor_custo"] == menor_custo]
linhas_melhores.head(len(linhas_melhores))
# Out:
#     pop_size  geracoes  elite_size  mutation_rate  \
# 4         50        50           2           0.10
# 12        50       100           2           0.05
# 13        50       100           2           0.10
# 16        50       100           4           0.10
# 22        50       200           2           0.10
# 48       100       200           2           0.05
# 52       100       200           4           0.10
# 53       100       200           4           0.15
# 59       150        50           2           0.15
# 62       150        50           4           0.15
# 63       150       100           1           0.05
# 65       150       100           1           0.15
# 70       150       100           4           0.10
#
#                     melhor_solucao  melhor_custo
# 4   [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 12  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 13  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 16  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 22  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 48  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 52  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 53  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 59  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 62  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 63  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 65  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0
# 70  [5, 8, 6, 4, 7, 3, 1, 9, 2, 0]       11676.0

# %%
# print(f"Quantidade de linhas com melhor custo: {len(linhas_melhores)}")
